# %%
import pandas as pd
from pathlib import Path


# Load the parquet file
df = pd.read_parquet("/data/rbg/users/dkwabiad/temp_while_cp_rsg/glycan_comp_restructure/output/metrics/glycans/results/glycoshape_vs_alphafold/pred_cryst_pairs.pqt")

# %%
df.groupby(["GSID", "Configuration"])["lddt"].describe()
# Out:
#                        count      mean       std       min       25%  \
# GSID    Configuration
# GS00029 beta            20.0  0.556967  0.018671  0.520744  0.548513
# GS00070 beta            25.0  0.904545  0.025675  0.874459  0.883117
# GS00073 beta            20.0  0.876398  0.033657  0.835558  0.844075
# GS00085 beta            30.0  0.898335  0.027443  0.857625  0.876432
# GS00090 beta            15.0  0.847196  0.054963  0.799787  0.806174
# GS00161 alpha           20.0  0.683967  0.021830  0.653986  0.667120
# GS00172 beta            15.0  0.881220  0.067917  0.812500  0.832880
# GS00178 beta            35.0  0.663072  0.047991  0.593999  0.621499
# GS00183 beta            40.0  0.630301  0.045220  0.558467  0.593863
# GS00184 beta            35.0  0.550370  0.048849  0.501925  0.508003
# GS00185 beta            30.0  0.566367  0.015688  0.539466  0.550567
# GS00186 alpha           35.0  0.708190  0.004467  0.701667  0.704583
# ...
